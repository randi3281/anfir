# %%
# install readxl package
install.packages("readxl")
install.packages("nortest")
rm(list = ls())
library(readxl)
BERATBADAN <- read_excel("BERATBADAN.xlsx")
BERATBADAN
# Out:
# Installing package into ‘/home/anfiniti/R/x86_64-pc-linux-gnu-library/4.1’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages("readxl"):
# “installation of package ‘readxl’ had non-zero exit status”
# Installing package into ‘/home/anfiniti/R/x86_64-pc-linux-gnu-library/4.1’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages("nortest"):
# “installation of package ‘nortest’ had non-zero exit status”
# Error: `path` does not exist: ‘BERATBADAN.xlsx’
# Traceback:
#
# 1. check_file(path)
# 2. stop("`path` does not exist: ", sQuote(path), call. = FALSE)
# 3. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = invokeRestart("eval_error",
#  .             cnd))
#  . }, "`path` does not exist: ‘BERATBADAN.xlsx’", base::quote(NULL))

# %%
View(BERATBADAN)
hist(BERATBADAN$BERAT)
qqnorm(BERATBADAN$BERAT)
qqline(BERATBADAN$BERAT)
# Out:
#    NO BERAT
# 1   1 45
# 2   2 50
# 3   3 55
# 4   4 55
# 5   5 60
# 6   6 60
# 7   7 60
# 8   8 70
# 9   9 70
# 10 10 80
# Plot with title “Histogram of BERATBADAN$BERAT”
# Plot with title “Normal Q-Q Plot”

# %%
library(nortest)
lillie.test(BERATBADAN$BERAT)
# Out:
# 	Lilliefors (Kolmogorov-Smirnov) normality test
#
# data:  BERATBADAN$BERAT
# D = 0.21918, p-value = 0.1891

# %%
shapiro.test(BERATBADAN$BERAT)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  BERATBADAN$BERAT
# W = 0.95584, p-value = 0.7376
